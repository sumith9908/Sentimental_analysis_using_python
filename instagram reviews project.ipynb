# %% [markdown]
# # Pre-Processing and Sentimental Analysis

# %%
#importing the libraries 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
df = pd.read_csv("Snapchat_app_store_reviews.csv", encoding='latin1')
df.shape
# Out:
# (9560, 7)

# %%
df.head()
# Out:
#    Unnamed: 0                userName  rating  \
# 0           0          Savvanananahhh       4
# 1           1           Idek 9-101112       3
# 2           2        William Quintana       3
# 3           3  an gonna be unkownð       5
# 4           4              gzhangziqi       1
#
#                                               review  isEdited           date  \
# 0  For the most part I quite enjoy Snapchat itâ...     False   10/4/20 6:01
# 1  Iâm sorry to say it, but something is defini...     False  10/14/20 2:13
# 2  Snapchat update ruined my story organization! ...     False  7/31/20 19:54
# 3  I really love the app for how long i have been...     False  4/22/21 14:10
# 4  This is super frustrating. I was in the middle...     False  10/2/20 13:58
#
#                                          title
# 0                           Performance issues
# 1                               What happened?
# 2                   STORY ORGANIZATION RUINED!
# ...

# %%
example = df['review']
print(example)
# Out:
# 0       For the most part I quite enjoy Snapchat itâ...
# 1       Iâm sorry to say it, but something is defini...
# 2       Snapchat update ruined my story organization! ...
# 3       I really love the app for how long i have been...
# 4       This is super frustrating. I was in the middle...
#                               ...
# 9555    I used to love using Snapchat and now I hardly...
# 9556    Well, I did deleted it because there was some ...
# 9557    Every time I upload a photo or video to my sto...
# 9558    Love this app, but since he update I canât u...
# 9559    Love Snapchat but for some reason when I post ...
# Name: review, Length: 9560, dtype: object

# %% [markdown]
# # NLTK Introduction

# %%
import nltk
import numpy as np
import matplotlib as mp

# %%
example = df['review'][1]

# %%
import nltk
from nltk.text import Text

# Sample text
text = example

# Tokenize the text
tokens = nltk.word_tokenize(text)

# Create an NLTK Text object
text_obj = Text(tokens)

# Use the concordance method
text_obj.concordance("snapchat")
# Out:
# Displaying 2 of 2 matches:
# something is definitely wrong with Snapchat . In all my years of using the app
#  been this disappointed . Although Snapchat is my main social app on my phone

# %%
text_obj.dispersion_plot(["fun", "chat" , "love","lot"])

# %%
len(example)
# Out:
# 1454

# %%
set(example)
# Out:
# {' ',
#  ',',
#  '.',
#  '4',
#  '5',
#  'A',
#  'B',
#  'E',
#  'F',
#  'I',
#  'J',
#  'K',
#  'L',
#  'M',
#  'S',
#  'T',
#  'U',
#  'W',
#  'a',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'v',
#  'w',
#  'x',
#  'y',
#  '\x80',
#  '\x99',
#  'â'}

# %%
sorted(set(example))
# Out:
# [' ',
#  ',',
#  '.',
#  '4',
#  '5',
#  'A',
#  'B',
#  'E',
#  'F',
#  'I',
#  'J',
#  'K',
#  'L',
#  'M',
#  'S',
#  'T',
#  'U',
#  'W',
#  'a',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'v',
#  'w',
#  'x',
#  'y',
#  '\x80',
#  '\x99',
#  'â']

# %%
len(set(example)) / len(example) # Lexical Richness
# Out:
# 0.030261348005502064

# %%
# word tokenization
print(example.split())
# Out:
# ['Iâ\x80\x99m', 'sorry', 'to', 'say', 'it,', 'but', 'something', 'is', 'definitely', 'wrong', 'with', 'Snapchat.', 'In', 'all', 'my', 'years', 'of', 'using', 'the', 'app,', 'I', 'have', 'never', 'been', 'this', 'disappointed.', 'Although', 'Snapchat', 'is', 'my', 'main', 'social', 'app', 'on', 'my', 'phone,', 'it', 'has', 'been', 'really', 'bugging', 'me.', 'For', 'example,', 'it', 'has', 'been', 'taking', 'up', 'to', '5', 'minutes', 'to', 'send', 'a', 'chat', 'everytime', 'I', 'try', 'to', 'send', 'something.', 'Before', 'I', 'am', 'told', 'my', 'phone', 'is', 'slow,', 'let', 'me', 'reassure', 'you', 'this', 'is', 'not', 'only', 'a', 'problem', 'for', 'me', 'but', 'for', 'my', 'peers', 'as', 'well.', 'Also,', 'I', 'have', 'been', 'receiving', 'Snapchatâ\x80\x99s', 'from', 'WEEKS', 'ago,', 'leaving', 'the', 'other', 'person', 'to', 'conclude', 'I', 'have', 'been', 'ignoring', 'them.', 'When', 'it', 'is', 'taking', '4', 'weeks', 'for', 'a', 'singular', 'snap', 'to', 'come', 'through,'
# ...

# %%
# sentence tokenizer
example.split('.')
# Out:
# ['Iâ\x80\x99m sorry to say it, but something is definitely wrong with Snapchat',
#  ' In all my years of using the app, I have never been this disappointed',
#  ' Although Snapchat is my main social app on my phone, it has been really bugging me',
#  ' For example, it has been taking up to 5 minutes to send a chat everytime I try to send something',
#  ' Before I am told my phone is slow, let me reassure you this is not only a problem for me but for my peers as well',
#  ' Also, I have been receiving Snapchatâ\x80\x99s from WEEKS ago, leaving the other person to conclude I have been ignoring them',
#  ' When it is taking 4 weeks for a singular snap to come through, there is an obvious problem with the app',
#  ' Likewise, my peers and I have noticed that when somebody responds to me, itâ\x80\x99s very slow and wonâ\x80\x99t load or I donâ\x80\x99t get it at all',
# ...

# %%
from nltk.tokenize import word_tokenize 
print(word_tokenize(example))
# Out:
# ['Iâ\x80\x99m', 'sorry', 'to', 'say', 'it', ',', 'but', 'something', 'is', 'definitely', 'wrong', 'with', 'Snapchat', '.', 'In', 'all', 'my', 'years', 'of', 'using', 'the', 'app', ',', 'I', 'have', 'never', 'been', 'this', 'disappointed', '.', 'Although', 'Snapchat', 'is', 'my', 'main', 'social', 'app', 'on', 'my', 'phone', ',', 'it', 'has', 'been', 'really', 'bugging', 'me', '.', 'For', 'example', ',', 'it', 'has', 'been', 'taking', 'up', 'to', '5', 'minutes', 'to', 'send', 'a', 'chat', 'everytime', 'I', 'try', 'to', 'send', 'something', '.', 'Before', 'I', 'am', 'told', 'my', 'phone', 'is', 'slow', ',', 'let', 'me', 'reassure', 'you', 'this', 'is', 'not', 'only', 'a', 'problem', 'for', 'me', 'but', 'for', 'my', 'peers', 'as', 'well', '.', 'Also', ',', 'I', 'have', 'been', 'receiving', 'Snapchatâ\x80\x99s', 'from', 'WEEKS', 'ago', ',', 'leaving', 'the', 'other', 'person', 'to', 'conclude', 'I', 'have', 'been', 'ignoring', 'them', '.', 'When', 'it', 'is', 'taking', '4', 'weeks', 'for
# ...

# %%
#sentence_tokenizer
from nltk.tokenize import sent_tokenize
sent_tokenize(example)
# Out:
# ['Iâ\x80\x99m sorry to say it, but something is definitely wrong with Snapchat.',
#  'In all my years of using the app, I have never been this disappointed.',
#  'Although Snapchat is my main social app on my phone, it has been really bugging me.',
#  'For example, it has been taking up to 5 minutes to send a chat everytime I try to send something.',
#  'Before I am told my phone is slow, let me reassure you this is not only a problem for me but for my peers as well.',
#  'Also, I have been receiving Snapchatâ\x80\x99s from WEEKS ago, leaving the other person to conclude I have been ignoring them.',
#  'When it is taking 4 weeks for a singular snap to come through, there is an obvious problem with the app.',
#  'Likewise, my peers and I have noticed that when somebody responds to me, itâ\x80\x99s very slow and wonâ\x80\x99t load or I donâ\x80\x99t get it at all.',
# ...

# %%
from nltk.tokenize import WhitespaceTokenizer
list(WhitespaceTokenizer().span_tokenize(example))
# Out:
# [(0, 5),
#  (6, 11),
#  (12, 14),
#  (15, 18),
#  (19, 22),
#  (23, 26),
#  (27, 36),
#  (37, 39),
#  (40, 50),
#  (51, 56),
#  (57, 61),
#  (62, 71),
#  (72, 74),
#  (75, 78),
#  (79, 81),
#  (82, 87),
#  (88, 90),
#  (91, 96),
#  (97, 100),
#  (101, 105),
#  (106, 107),
#  (108, 112),
#  (113, 118),
#  (119, 123),
#  (124, 128),
#  (129, 142),
#  (143, 151),
#  (152, 160),
#  (161, 163),
#  (164, 166),
#  (167, 171),
#  (172, 178),
#  (179, 182),
#  (183, 185),
#  (186, 188),
#  (189, 195),
#  (196, 198),
#  (199, 202),
#  (203, 207),
#  (208, 214),
#  (215, 222),
#  (223, 226),
#  (227, 230),
#  (231, 239),
#  (240, 242),
#  (243, 246),
#  (247, 251),
#  (252, 258),
#  (259, 261),
#  (262, 264),
#  (265, 266),
#  (267, 274),
#  (275, 277),
#  (278, 282),
#  (283, 284),
#  (285, 289),
#  (290, 299),
#  (300, 301),
#  (302, 305),
#  (306, 308),
#  (309, 313),
#  (314, 324),
#  (325, 331),
#  (332, 333),
#  (334, 336),
#  (337, 341),
#  (342, 344),
#  (345, 350),
#  (351, 353),
# ...

# %% [markdown]
# # Stop Words and POS Tagging
# # Filtering Stop Words

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
 
stop_words = set(stopwords.words('english'))    #List of Stop Words
 
word_tokens = word_tokenize(example)       # Tokens (ALL)
print(word_tokens)

# converts the words in word_tokens to lower case and then checks whether 
#they are present in stop_words or not
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]  
print(filtered_sentence)



filtered_sentence = []
for w in word_tokens:
    if w not in stop_words: #Not taking case into consideration
        filtered_sentence.append(w)
print(filtered_sentence)
# Out:
# ['Iâ\x80\x99m', 'sorry', 'to', 'say', 'it', ',', 'but', 'something', 'is', 'definitely', 'wrong', 'with', 'Snapchat', '.', 'In', 'all', 'my', 'years', 'of', 'using', 'the', 'app', ',', 'I', 'have', 'never', 'been', 'this', 'disappointed', '.', 'Although', 'Snapchat', 'is', 'my', 'main', 'social', 'app', 'on', 'my', 'phone', ',', 'it', 'has', 'been', 'really', 'bugging', 'me', '.', 'For', 'example', ',', 'it', 'has', 'been', 'taking', 'up', 'to', '5', 'minutes', 'to', 'send', 'a', 'chat', 'everytime', 'I', 'try', 'to', 'send', 'something', '.', 'Before', 'I', 'am', 'told', 'my', 'phone', 'is', 'slow', ',', 'let', 'me', 'reassure', 'you', 'this', 'is', 'not', 'only', 'a', 'problem', 'for', 'me', 'but', 'for', 'my', 'peers', 'as', 'well', '.', 'Also', ',', 'I', 'have', 'been', 'receiving', 'Snapchatâ\x80\x99s', 'from', 'WEEKS', 'ago', ',', 'leaving', 'the', 'other', 'person', 'to', 'conclude', 'I', 'have', 'been', 'ignoring', 'them', '.', 'When', 'it', 'is', 'taking', '4', 'weeks', 'for
# ...

# %% [markdown]
# # POS Tagging (parts of speech)
#
# POS Tagging (Part-of-Speech Tagging):
#
# POS tagging is a process in natural language processing (NLP) where each word in a sentence is labeled with its corresponding part of speech, such as noun, verb, adjective, etc.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
stop_words = set(stopwords.words('english'))


 
tokenized = sent_tokenize(example)
for i in tokenized:
     
   
    wordsList = nltk.word_tokenize(i)
 
    # removing stop words from wordList
    wordsList = [w for w in wordsList if not w in stop_words] 
 
    #  Using a Tagger. Which is part-of-speech 
    # tagger or POS-tagger. 
    tagged = nltk.pos_tag(wordsList)
    print(example)
    print(tagged)
# Out:
# Iâm sorry to say it, but something is definitely wrong with Snapchat. In all my years of using the app, I have never been this disappointed. Although Snapchat is my main social app on my phone, it has been really bugging me. For example, it has been taking up to 5 minutes to send a chat everytime I try to send something. Before I am told my phone is slow, let me reassure you this is not only a problem for me but for my peers as well. Also, I have been receiving Snapchatâs from WEEKS ago, leaving the other person to conclude I have been ignoring them. When it is taking 4 weeks for a singular snap to come through, there is an obvious problem with the app. Likewise, my peers and I have noticed that when somebody responds to me, itâs very slow and wonât load or I donât get it at all. Just the other day I received a snap, and when I asked about it I learned it had said I left them on opened whereas for me it said I had been left on delivered. The amount of time I have wasted try
# ...

# %%
from nltk import pos_tag
from nltk import word_tokenize
 
tokenized_text = word_tokenize(example)
tags = tokens_tag = pos_tag(tokenized_text)
tags
# Out:
# [('Iâ\x80\x99m', 'NNP'),
#  ('sorry', 'NN'),
#  ('to', 'TO'),
#  ('say', 'VB'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('but', 'CC'),
#  ('something', 'NN'),
#  ('is', 'VBZ'),
#  ('definitely', 'RB'),
#  ('wrong', 'JJ'),
#  ('with', 'IN'),
#  ('Snapchat', 'NNP'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('all', 'DT'),
#  ('my', 'PRP$'),
#  ('years', 'NNS'),
#  ('of', 'IN'),
#  ('using', 'VBG'),
#  ('the', 'DT'),
#  ('app', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('never', 'RB'),
#  ('been', 'VBN'),
#  ('this', 'DT'),
#  ('disappointed', 'JJ'),
#  ('.', '.'),
#  ('Although', 'IN'),
#  ('Snapchat', 'NNP'),
#  ('is', 'VBZ'),
#  ('my', 'PRP$'),
#  ('main', 'JJ'),
#  ('social', 'JJ'),
#  ('app', 'NN'),
#  ('on', 'IN'),
#  ('my', 'PRP$'),
#  ('phone', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('really', 'RB'),
#  ('bugging', 'VBG'),
#  ('me', 'PRP'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('example', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
# ...

# %%
(example.count("a")/len(example))*100 # TERM FREQUENCY TF_IDF
# Out:
# 5.364511691884457

# %%
import re                                #Regular Expression
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Convert text to lowercase
text = example
print(text)
text = text.lower()
print(text)



text = re.sub(r'[^a-zA-Z\s]', '', text)
print(text)
# Out:
# Iâm sorry to say it, but something is definitely wrong with Snapchat. In all my years of using the app, I have never been this disappointed. Although Snapchat is my main social app on my phone, it has been really bugging me. For example, it has been taking up to 5 minutes to send a chat everytime I try to send something. Before I am told my phone is slow, let me reassure you this is not only a problem for me but for my peers as well. Also, I have been receiving Snapchatâs from WEEKS ago, leaving the other person to conclude I have been ignoring them. When it is taking 4 weeks for a singular snap to come through, there is an obvious problem with the app. Likewise, my peers and I have noticed that when somebody responds to me, itâs very slow and wonât load or I donât get it at all. Just the other day I received a snap, and when I asked about it I learned it had said I left them on opened whereas for me it said I had been left on delivered. The amount of time I have wasted try
# ...

# %% [markdown]
# # Entities
# Entities in Natural Language Processing (NLP):
#
# In NLP, entities refer to specific types of objects or concepts mentioned in text, such as names of people, organizations, locations, dates, and numerical values

# %%
import nltk

# Download necessary NLTK data packages
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# ## SPACY
#
# spaCy is a popular Python library used for NLP tasks like tokenization, POS tagging, named entity recognition, and more.

# %%
import pandas as pd

# Assuming you have a CSV file named 'data.csv' containing a column 'review'
df = pd.read_csv('snapchat_app_store_reviews.csv')

# Access an example review
example = df['review'][17]
print(example)
# Out:
# I was really impressed with Snapchat back in the day, in that it enabled photo messaging and added filters to help with those of us who may have a bad skin day, keep our blemishes hidden by a smoother so when we send our friends a snap it doesn’t show our embarrassing acne spot to our possible crush, etc. The new updates to Snapchat are disastrous. First; I can not clear an entire conversation column and have to go one by one through the messages to clear them. Also you can’t look up your friends; how is anyone supposed to organize their friends list if we can’t even see who’s our friend without searching them? If you have 20 or so friends you are basically spending 2 minutes of your time trying to clear your snap window. Second; the stories; filled with biased propaganda and absolute garbage. I enjoy subscribing to some of the channels but the fact that most of these channels feature some of the most controversial topics and are completely one sided is unfortunate. I would like to s
# ...

# %%
#!pip install spacy
# Execute the following command in your terminal or command promp
#!python -m spacy download en_core_web_sm

# %%
import spacy
obj = spacy.load("en_core_web_sm") 
doc = obj(example)
print("_________________________________________________________________________________")
for token in doc :
 print(token.text, token.pos_, token.dep_) #depth is discription of pos tag.
# Out:
# _________________________________________________________________________________
# I PRON nsubj
# was AUX ROOT
# really ADV advmod
# impressed ADJ acomp
# with ADP prep
# Snapchat PROPN pobj
# back ADV advmod
# in ADP prep
# the DET det
# day NOUN pobj
# , PUNCT punct
# in SCONJ mark
# that SCONJ mark
# it PRON nsubj
# enabled VERB advcl
# photo NOUN compound
# messaging NOUN dobj
# and CCONJ cc
# added VERB conj
# filters NOUN dobj
# to PART aux
# help VERB xcomp
# with ADP prep
# those PRON pobj
# of ADP prep
# us PRON pobj
# who PRON nsubj
# may AUX aux
# have VERB relcl
# a DET det
# bad ADJ amod
# skin NOUN compound
# day NOUN dobj
# , PUNCT punct
# keep VERB conj
# our PRON poss
# blemishes NOUN dobj
# hidden VERB acl
# by ADP agent
# a DET det
# smoother NOUN pobj
# so ADV advmod
# when SCONJ advmod
# we PRON nsubj
# send VERB advcl
# our PRON poss
# friends NOUN dobj
# a DET det
# snap NOUN dobj
# it PRON nsubj
# does AUX aux
# n’t PART neg
# show VERB relcl
# our PRON poss
# ...

# %%
obj = spacy.load("en_core_web_sm") #object of class #(sm is source model, lm is language model)

doc = obj(example)
print("_______________________________________________________________________")
for token in doc :
 print(token.text, token.pos_, token.dep_) #depth is discription of pos tag.
# Out:
# _______________________________________________________________________
# I PRON nsubj
# was AUX ROOT
# really ADV advmod
# impressed ADJ acomp
# with ADP prep
# Snapchat PROPN pobj
# back ADV advmod
# in ADP prep
# the DET det
# day NOUN pobj
# , PUNCT punct
# in SCONJ mark
# that SCONJ mark
# it PRON nsubj
# enabled VERB advcl
# photo NOUN compound
# messaging NOUN dobj
# and CCONJ cc
# added VERB conj
# filters NOUN dobj
# to PART aux
# help VERB xcomp
# with ADP prep
# those PRON pobj
# of ADP prep
# us PRON pobj
# who PRON nsubj
# may AUX aux
# have VERB relcl
# a DET det
# bad ADJ amod
# skin NOUN compound
# day NOUN dobj
# , PUNCT punct
# keep VERB conj
# our PRON poss
# blemishes NOUN dobj
# hidden VERB acl
# by ADP agent
# a DET det
# smoother NOUN pobj
# so ADV advmod
# when SCONJ advmod
# we PRON nsubj
# send VERB advcl
# our PRON poss
# friends NOUN dobj
# a DET det
# snap NOUN dobj
# it PRON nsubj
# does AUX aux
# n’t PART neg
# show VERB relcl
# our PRON poss
# ...

# %%
import spacy 
obj = spacy.load("en_core_web_sm") 

#Create an nlp Object
rel = obj(example)

# Iterate over the tokens
for token in rel : 
    # Print tokens and their part-of-speech tag
    print(token, "-->", token.tag_, "-->", token.pos_, "-->")
# Out:
# I --> PRP --> PRON -->
# was --> VBD --> AUX -->
# really --> RB --> ADV -->
# impressed --> JJ --> ADJ -->
# with --> IN --> ADP -->
# Snapchat --> NNP --> PROPN -->
# back --> RB --> ADV -->
# in --> IN --> ADP -->
# the --> DT --> DET -->
# day --> NN --> NOUN -->
# , --> , --> PUNCT -->
# in --> IN --> SCONJ -->
# that --> IN --> SCONJ -->
# it --> PRP --> PRON -->
# enabled --> VBD --> VERB -->
# photo --> NN --> NOUN -->
# messaging --> NN --> NOUN -->
# and --> CC --> CCONJ -->
# added --> VBN --> VERB -->
# filters --> NNS --> NOUN -->
# to --> TO --> PART -->
# help --> VB --> VERB -->
# with --> IN --> ADP -->
# those --> DT --> PRON -->
# of --> IN --> ADP -->
# us --> PRP --> PRON -->
# who --> WP --> PRON -->
# may --> MD --> AUX -->
# have --> VB --> VERB -->
# a --> DT --> DET -->
# bad --> JJ --> ADJ -->
# skin --> NN --> NOUN -->
# day --> NN --> NOUN -->
# , --> , --> PUNCT -->
# keep --> VB --> VERB -->
# our --> PRP$ --> PRON -->
# blemishes --> NNS --> NOUN -->
# ...

# %%
import spacy
obj = spacy.load("en_core_web_sm") # Object of class Spacy 

# Create an obj object 
rel = obj(example)

# Iterate over the tokens 
for token in rel:
    # Print the token and its parts-of-speech tag 
    print(token, "---->", token.tag_, "---->", token.pos_,"---->", spacy.explain(token.tag_))
# Out:
# I ----> PRP ----> PRON ----> pronoun, personal
# was ----> VBD ----> AUX ----> verb, past tense
# really ----> RB ----> ADV ----> adverb
# impressed ----> JJ ----> ADJ ----> adjective (English), other noun-modifier (Chinese)
# with ----> IN ----> ADP ----> conjunction, subordinating or preposition
# Snapchat ----> NNP ----> PROPN ----> noun, proper singular
# back ----> RB ----> ADV ----> adverb
# in ----> IN ----> ADP ----> conjunction, subordinating or preposition
# the ----> DT ----> DET ----> determiner
# day ----> NN ----> NOUN ----> noun, singular or mass
# , ----> , ----> PUNCT ----> punctuation mark, comma
# in ----> IN ----> SCONJ ----> conjunction, subordinating or preposition
# that ----> IN ----> SCONJ ----> conjunction, subordinating or preposition
# it ----> PRP ----> PRON ----> pronoun, personal
# enabled ----> VBD ----> VERB ----> verb, past tense
# photo ----> NN ----> NOUN ----> noun, singular or mass
# messaging ----> NN ----> NOUN ----> noun, singular or mass
# ...

# %%
import spacy 
from spacy import displacy 
nlp = spacy.load("en_core_web_sm") 

doc = nlp(example)
displacy.render(doc, style = "dep", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="847a3740189441c2bf129e0747f2b988-0" class="displacy" width="40125" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
# ...

# %%
for word in rel.ents:
    print(word.text, word.label_)
# Out:
# the day DATE
# First ORDINAL
# 20 or CARDINAL
# 2 minutes TIME
# Second ORDINAL
# one CARDINAL

# %%
for ent in rel.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# the day 45 52 DATE
# First 351 356 ORDINAL
# 20 or 631 636 CARDINAL
# 2 minutes 675 684 TIME
# Second 732 738 ORDINAL
# one 955 958 CARDINAL

# %%
spacy.explain("FAC")
# Out:
# 'Buildings, airports, highways, bridges, etc.'

# %%
displacy.render(rel, style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I was really impressed with Snapchat back in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , in that it enabled photo messaging and added filters to help with those of us who may have a bad skin day, keep our blemishes hidden by a smoother so when we send our friends a snap it doesn’t show our embarrassing acne spot to our possible crush, etc. The new updates to Snapchat are disastrous.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
# ...

# %% [markdown]
# # Sentimental Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
#Downscale
df = df.head(3000)
print(df.shape)
df.head()
# Out:
# (3000, 7)
#    Unnamed: 0             userName  rating  \
# 0           0       Savvanananahhh       4
# 1           1        Idek 9-101112       3
# 2           2     William Quintana       3
# 3           3  an gonna be unkown😏       5
# 4           4           gzhangziqi       1
#
#                                               review  isEdited           date  \
# 0  For the most part I quite enjoy Snapchat it’s ...     False   10/4/20 6:01
# 1  I’m sorry to say it, but something is definite...     False  10/14/20 2:13
# 2  Snapchat update ruined my story organization! ...     False  7/31/20 19:54
# 3  I really love the app for how long i have been...     False  4/22/21 14:10
# 4  This is super frustrating. I was in the middle...     False  10/2/20 13:58
#
#                                          title
# 0                           Performance issues
# 1                               What happened?
# 2                   STORY ORGANIZATION RUINED!
# ...

# %% [markdown]
# # Quick EDA

# %%
ax = df['rating'].value_counts().sort_index() \
          .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('rating')
plt.show()

# %% [markdown]
# # Basic NLTK

# %%
example = df['review'][10]
print(example)
# Out:
# So I recently just got the current update of Snapchat and it myself as well as many people that I know don’t necessarily like it. It changes the flow a bit too much and there are now some features that don’t exist anymore. I do like being able to access the snap map better by clicking on it however I do not like that when I swipe to the left instead of opening a conversation it goes to the map. Many of us would rather be able to swipe into our conversations like we used to. I understand that the update was most likely a lot of work but I think it would be nice if we could get the option to decide if swiping left will open chats or the map. May be in a next update you can add in a feature in our settings where you can pick whether swiping left or open the map or your chats I’m sure many people would appreciate it although I do understand it would take a lot of work. Either way Snapchat is an amazing app and really this is just a small problem but one that I feel many people would appr
# ...

# %%
tokens = nltk.word_tokenize(example)
tokens[:12]
# Out:
# ['So',
#  'I',
#  'recently',
#  'just',
#  'got',
#  'the',
#  'current',
#  'update',
#  'of',
#  'Snapchat',
#  'and',
#  'it']

# %%
tagged = nltk.pos_tag(tokens)
tagged[-5:]
# Out:
# [('still', 'RB'), ('love', 'VBP'), ('the', 'DT'), ('app', 'NN'), ('.', '.')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
print(entities)
#entities.pprint()
# Out:
# (S
#   So/RB
#   I/PRP
#   recently/RB
#   just/RB
#   got/VBD
#   the/DT
#   current/JJ
#   update/NN
#   of/IN
#   (GPE Snapchat/NNP)
#   and/CC
#   it/PRP
#   myself/PRP
#   as/RB
#   well/RB
#   as/IN
#   many/JJ
#   people/NNS
#   that/IN
#   I/PRP
#   know/VBP
#   don/JJ
#   ’/NNP
#   t/VBD
#   necessarily/RB
#   like/IN
#   it/PRP
#   ./.
#   It/PRP
#   changes/VBZ
#   the/DT
#   flow/NN
#   a/DT
#   bit/RB
#   too/RB
#   much/JJ
#   and/CC
#   there/EX
#   are/VBP
#   now/RB
#   some/DT
#   features/NNS
#   that/IN
#   don/VBP
#   ’/JJ
#   t/NNS
#   exist/VBP
#   anymore/RB
#   ./.
#   I/PRP
#   do/VBP
#   like/IN
#   being/VBG
#   able/JJ
#   to/TO
#   access/NN
#   the/DT
#   snap/NN
#   map/NN
#   better/RBR
#   by/IN
#   clicking/VBG
#   on/IN
#   it/PRP
#   however/RB
#   I/PRP
#   do/VBP
#   not/RB
#   like/IN
#   that/DT
#   when/WRB
#   I/PRP
#   swipe/VBP
#   to/TO
#   the/DT
#   left/VBN
#   instead/RB
#   of/IN
#   opening/VBG
#   a/DT
#   conversation/NN
# ...

# %% [markdown]
# # Step 1. VADER Sentiment Scoring

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from tqdm import tqdm

# Download NLTK data
nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()

# Example usage of tqdm
for i in tqdm(range(10)):
    # Your code here
    pass
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# 100%|██████████| 10/10 [00:00<?, ?it/s]

# %%
sia.polarity_scores('Ok so snapchat is amazing and I’ve been using it for a long time now, but today this weird glitch keeps happening. Every time I try to upload something on my story it does not work, and every time I refresh a page it says could not refresh but it doesn’t pop up til like 15 seconds later. Every other app that uses internet on my iPad works. I think it is a glitch within Snapchat, because I have tried logging in and out, turning off WiFi and turning back on, restarting iPad, or all 3 of those things, still the same thing happens. I’m not sure if it’s something with my account, but I would really appreciate if you would look into this. My account name is twentythreekc and I’m using an iPad Air. Thank you!!!')
# Out:
# {'neg': 0.034, 'neu': 0.857, 'pos': 0.11, 'compound': 0.8943}

# %%
sia.polarity_scores('I absolutely hate the new interface. It’s hard to use and messes with my pattern. I have a specific way of opening messages and this new interface completely screws with that. It’s buggy and a lot glitchier than before the interface was changed. My other friends & family don’t have the new layout. I’m rating this 1 star until my layout changes back to normal. I absolutely hate it. Especially as someone who doesn’t even use snap maps, the new placement is ridiculous. I can’t even view the stories I’m subscribed to without them automatically opening them and become impossible to close (a glitch) unless I force close & reopen the app. My friends have taken a look at the layout from my phone and hate the layout as much as me and keep telling me that they’re lucky theirs hasn’t changed. Please snapchat do not keep this absolutely hideous and unusable interface. It’s disgusting.')
# Out:
# {'neg': 0.13, 'neu': 0.802, 'pos': 0.068, 'compound': -0.8826}

# %%
# Run the polarity score on the entire dataset 
extdata ={}
for i, row in tqdm(df.iterrows(), total = len(df)):
    text = row['review']
    myid = row['rating']
    extdata[myid] = sia.polarity_scores(text)
# Out:
# 100%|██████████| 3000/3000 [00:04<00:00, 600.63it/s]

# %%
# Assuming 'index' is the common column name in both DataFrames
vaders = pd.DataFrame(extdata).T
vaders = vaders.reset_index().rename(columns={'review': 'userName'})

# Merge based on the index of both DataFrames
vaders = vaders.merge(df, left_index=True, right_index=True, how='left')

# %%
vaders.head()
# Out:
#    index    neg    neu    pos  compound  Unnamed: 0             userName  \
# 0      4  0.131  0.742  0.127   -0.0900           0       Savvanananahhh
# 1      3  0.029  0.923  0.048    0.3947           1        Idek 9-101112
# 2      5  0.042  0.817  0.141    0.7882           2     William Quintana
# 3      1  0.063  0.831  0.106    0.7623           3  an gonna be unkown😏
# 4      2  0.038  0.877  0.085    0.7105           4           gzhangziqi
#
#    rating                                             review  isEdited  \
# 0       4  For the most part I quite enjoy Snapchat it’s ...     False
# 1       3  I’m sorry to say it, but something is definite...     False
# 2       3  Snapchat update ruined my story organization! ...     False
# 3       5  I really love the app for how long i have been...     False
# 4       1  This is super frustrating. I was in the middle...     False
#
#             date                                        title
# ...

# %% [markdown]
# # Plot VADER results

# %%
ax = sns.barplot(data=vaders, x='rating', y='compound')
ax.set_title('Compund Score by Snapchat Review')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='rating', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='rating', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='rating', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Roberta

# %%
print(example)
# Out:
# So I recently just got the current update of Snapchat and it myself as well as many people that I know don’t necessarily like it. It changes the flow a bit too much and there are now some features that don’t exist anymore. I do like being able to access the snap map better by clicking on it however I do not like that when I swipe to the left instead of opening a conversation it goes to the map. Many of us would rather be able to swipe into our conversations like we used to. I understand that the update was most likely a lot of work but I think it would be nice if we could get the option to decide if swiping left will open chats or the map. May be in a next update you can add in a feature in our settings where you can pick whether swiping left or open the map or your chats I’m sure many people would appreciate it although I do understand it would take a lot of work. Either way Snapchat is an amazing app and really this is just a small problem but one that I feel many people would appr
# ...

# %%
# VADER results on example
print(example)
sia.polarity_scores(example)
# Out:
# So I recently just got the current update of Snapchat and it myself as well as many people that I know don’t necessarily like it. It changes the flow a bit too much and there are now some features that don’t exist anymore. I do like being able to access the snap map better by clicking on it however I do not like that when I swipe to the left instead of opening a conversation it goes to the map. Many of us would rather be able to swipe into our conversations like we used to. I understand that the update was most likely a lot of work but I think it would be nice if we could get the option to decide if swiping left will open chats or the map. May be in a next update you can add in a feature in our settings where you can pick whether swiping left or open the map or your chats I’m sure many people would appreciate it although I do understand it would take a lot of work. Either way Snapchat is an amazing app and really this is just a small problem but one that I feel many people would appr
# ...

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
#pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu11

# %%
data_t = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(data_t)
model = AutoModelForSequenceClassification.from_pretrained(data_t)

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
'roberta_neg' : scores[0],
'roberta_neu' : scores[1],
'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.106833436, 'roberta_neu': 0.29816177, 'roberta_pos': 0.5950048}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = str(row['rating']) # Convert integer to string
        myid = row['userName']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
# 100%|██████████| 3000/3000 [02:12<00:00, 22.71it/s]

# %% [markdown]
# # Compare Scores between models

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'userName'})
results_df = results_df.merge(df, how='left')
results_df.head()
# Out:
#               userName  vader_neg  vader_neu  vader_pos  vader_compound  \
# 0       Savvanananahhh        0.0        0.0        0.0             0.0
# 1        Idek 9-101112        0.0        0.0        0.0             0.0
# 2     William Quintana        0.0        0.0        0.0             0.0
# 3  an gonna be unkown😏        0.0        0.0        0.0             0.0
# 4           gzhangziqi        0.0        0.0        0.0             0.0
#
#    roberta_neg  roberta_neu  roberta_pos  Unnamed: 0  rating  \
# 0     0.238232     0.488244     0.273524           0       4
# 1     0.211449     0.499271     0.289280           1       3
# 2     0.211449     0.499271     0.289280           2       3
# 3     0.222411     0.501255     0.276334           3       5
# 4     0.224572     0.496509     0.278919           4       1
#
#                                               review  isEdited           date  \
# 0  For the most part I quite enjoy Snapchat it’s ...     False   10/4/20 6:01
# ...

# %%
results_df.columns
# Out:
# Index(['userName', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'Unnamed: 0', 'rating',
#        'review', 'isEdited', 'date', 'title'],
#       dtype='object')

# %%
#JUST TO UNDERSTAND

vader_r_rename = {'va': 1, 'vb': 2}
roberta_r = {'rb': 3, 'rc': 4}

both = {**vader_r_rename, **roberta_r}

print(both)
# Out:
# {'va': 1, 'vb': 2, 'rb': 3, 'rc': 4}

# %%
sns.pairplot(data=results_df,
vars=['vader_neg', 'vader_neu', 'vader_pos',
'roberta_neg', 'roberta_neu', 'roberta_pos'],
hue='rating',
palette='tab10')
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Review Examples:

# %%
results_df.query('rating == 1') \
    .sort_values('roberta_pos', ascending=False)['review'].values[0]
# Out:
# 'This is super frustrating. I was in the middle of sending a Snapchat when the app logged me out. I tried logging in and it said I was temporarily locked from my account. It has been more than 48 hours and I have reached out to Snapchat support on Twitter multiple times and sent multiple requests through their support website, ans they never send any confirmations or case/ticket numbers with your request so all I can think of is that they’re not even reading anything anymore.  So many people are experiencing this issue, just look at all of Snapchat support’s twitter and the replies. Customer service is freaking terrible and I’m using this as a last resort. They keep sending the same tweet over and over again about how an account can be locked, but they’re not helping unlock legit accounts. They sent me a link to unlock legit accounts, but it’s is not working and basically my account is still there but I am locked out of it and I can’t get Snapchat to unlock it or tell me how to unloc
# ...

# %%
results_df.query('rating == 1') \
    .sort_values('vader_pos', ascending=False)['review'].values[0]
# Out:
# 'This is super frustrating. I was in the middle of sending a Snapchat when the app logged me out. I tried logging in and it said I was temporarily locked from my account. It has been more than 48 hours and I have reached out to Snapchat support on Twitter multiple times and sent multiple requests through their support website, ans they never send any confirmations or case/ticket numbers with your request so all I can think of is that they’re not even reading anything anymore.  So many people are experiencing this issue, just look at all of Snapchat support’s twitter and the replies. Customer service is freaking terrible and I’m using this as a last resort. They keep sending the same tweet over and over again about how an account can be locked, but they’re not helping unlock legit accounts. They sent me a link to unlock legit accounts, but it’s is not working and basically my account is still there but I am locked out of it and I can’t get Snapchat to unlock it or tell me how to unloc
# ...

# %%
# negative sentiment but 5-Star view

# %%
results_df.query('rating == 5') \
    .sort_values('roberta_neg', ascending=False)['review'].values[0]
# Out:
# "I really love the app for how long i have been using it i can say that it has had some difficulties i also have had some request to a new update for snapchat. Not many people are going to like the idea of this but maybe saving chat can be taken off my phone gets checked and i have friends that are very...yk💀and they save every little chat they send in out gc and every time my phone gets checked since am still a child ofc😀i get in trouble and grounded for the things they send💀u dont wanna know..but anyways thats a request i was also thinking to give dark mode out i have heard they where thinking to do dark mode but i heard that long ago i was also thinking to take out snap call i rlly dont know why i dont like snap call its jus..dumb in a way..if its called snapchat y is there call in there if we have facetime or any other app any other device uses to call in my opinion i dont like snap call...idky i also request to maybe when u send a chat it give u a notif of what the person said b
# ...

# %%
results_df.query('rating == 5') \
    .sort_values('vader_neg', ascending=False)['review'].values[0]
# Out:
# "I really love the app for how long i have been using it i can say that it has had some difficulties i also have had some request to a new update for snapchat. Not many people are going to like the idea of this but maybe saving chat can be taken off my phone gets checked and i have friends that are very...yk💀and they save every little chat they send in out gc and every time my phone gets checked since am still a child ofc😀i get in trouble and grounded for the things they send💀u dont wanna know..but anyways thats a request i was also thinking to give dark mode out i have heard they where thinking to do dark mode but i heard that long ago i was also thinking to take out snap call i rlly dont know why i dont like snap call its jus..dumb in a way..if its called snapchat y is there call in there if we have facetime or any other app any other device uses to call in my opinion i dont like snap call...idky i also request to maybe when u send a chat it give u a notif of what the person said b
# ...
